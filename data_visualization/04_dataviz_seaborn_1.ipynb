# %% [markdown]
# # _**Data Visualization**_
# # _**Basic Plots Using Seaborn Part 2**_

# %% [markdown]
# Author: Anwar Mehmood Sohail\
# Date: 31 October, 2023\
# Email: anwarmehmood.sohail@gmail.com
#
# #dataviz #datavisualization #codanics
#
# ----

# %% [markdown]
# > We will see following plots in this notebook
#
# >- Relational Plot
# >- Distribution Plot
# >- Categorical Plot
# >- Regression Plot
# >- Matrix Plot
# > - Multiplots

# %%
# Import libararies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import two datasets from seaborn
iris = sns.load_dataset('iris') # Iris dataset
tips = sns.load_dataset('tips') # Tips dataset

# %%
# to disable the warnings
import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# # _**1. Relational Plot**_
# ## _**Relationlal plot is used for Bivaraite Analysis, means to see the relationship between 2 or more vairables/columns/features.**_
# - Scatter Plot
# - Lineplot

# %% [markdown]
# ## _**1.1 Scatter Plot:**_

# %%
# to check the columns of data
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# To plot simple scatter plot we need to give data, x, and y
# ploting using axes level funciton
sns.scatterplot(data=iris, x='petal_length', y='sepal_length')
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_length'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# to add three more parameters, hue, style, and size (ususally these numbers are categorical data)
# ploting using axes level funciton
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='sex', style='smoker', size='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## _**1.2 Line Plot:**_

# %% [markdown]
# Line plot is used with time variable on the x axis

# %%
# load dataset having time variable
import plotly.express as px
gapminder = px.data.gapminder()
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
# to get only Pakistan, India and Bangladesh data we can use either command
#gapminder[(gapminder['country'] == 'Pakistan') | (gapminder['country'] == 'India') | (gapminder['country'] == 'Afghanistan')]
ipb = gapminder[gapminder['country'].isin(['Pakistan', 'India', 'Afghanistan'])] # ipb stands for India, Pakistan, Bangladesh
ipb.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
# plot line plot on year basis (x axix)
sns.lineplot(data=ipb, x='year', y='lifeExp', hue='country')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
# ploting using figure level funciton (relplot)
sns.relplot(kind='line', data=ipb, x='year', y='lifeExp', hue='country', style='iso_alpha', size='country')

# %%
# ploting using figure level funciton (relplot) which include 'col' parameter to plot more plot in one figure
sns.relplot(kind='scatter', data=tips, x='total_bill', y='tip', hue='sex', style='smoker', size='tip', col='day', col_wrap=2)

# %% [markdown]
# # 2. Distribution Plots
#
# - used for univariate analysis
# - used to find out the distribution
#
# Plots under distribution plot
#
# - histplot
# - kdeplot

# %% [markdown]
# ## 2.1 Histogram

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# figure leve function
sns.displot(data=iris, kind='hist', x='petal_length')

# %%
sns.displot(data=iris, kind='hist', x='petal_length', hue='species')

# %%
# to make transparent
sns.displot(data=iris, kind='hist', x='petal_length', hue='species', element='step')

# %%
# to make more plots
sns.displot(data=iris, kind='hist', x='petal_length', col='species')

# %% [markdown]
# ## 2.1 Kde plot

# %%
sns.displot(data=iris, kind='kde', x='petal_length')

# %%
sns.displot(data=iris, kind='kde', x='petal_length', hue='species')

# %%
# fill
sns.displot(data=iris, kind='kde', x='petal_length', hue='species', fill=True)
